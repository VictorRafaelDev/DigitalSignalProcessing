# %% [markdown]
# ---
#
# ### **Capítulo 4**
#
#
# Este Capítulo foca na Transformada Z e suas aplicações em análise e processamento de sinais digitais. Este resumo está estruturado para explorar conceitos fundamentais, propriedades, e técnicas práticas usando a Transformada Z, além de resolver problemas e analisar sistemas.
#
#
# ### Principais Pontos
#
# ---
#
# ### 🟢 **Transformada Z de Sequências (P4.1)**
# - **Problema:**
#   Determine a Transformada Z para as seguintes sequências:
#   1. \( x(n) = \{1, 2, 3, 4\} \) para \( n = 0, 1, 2, 3 \).
#
#   2. \( x(n) = 2^n u(n) \), onde \(u(n)\) é a função de Heaviside.
#   3. \( x(n) = \sin(\pi n / 4) \cdot u(n) \).
#
# - **Objetivo:**
#   Calcular a Transformada Z utilizando a definição e comparar os resultados com MATLAB. A análise verifica os resultados teóricos por meio de simulações práticas.
#
#
# ---
#
# ### 🟢 **Relação entre \( Y(z) \) e \( X(z) \) (P4.2)**
# - **Problema:**
#   Encontre \( Y(z) \) para \( y(n) = x(n/2) \), onde \( x(n) \) é uma sequência conhecida.
#
# - **Objetivo:**
#   Aplicar a propriedade de escalonamento da Transformada Z e entender como a alteração na sequência afeta sua Transformada Z.
#
#
# ---
#
# ### 🟢 **Propriedades da Transformada Z (P4.3)**
# - **Problema:**
#   Encontre a Transformada Z de:
#   1. \( \delta(n) \), a função delta de Dirac discreta.
#   2. \( a^n u(n) \), uma sequência geométrica.
#   3. \( n a^n u(n) \), uma sequência geométrica ponderada por \(n\).
#
# - **Objetivo:**
#   Utilizar tabelas e verificar os resultados no MATLAB para validar propriedades fundamentais da Transformada Z.
#
#
# ---
#
# ### 🟢 **Partes Real e Imaginária (P4.4)**
# - **Problema:**
#   Determine as partes real e imaginária da função \( H(z) = \frac{z}{z - a} \).
#
# - **Objetivo:**
#   Separar as partes real e imaginária e analisar as implicações na resposta do sistema.
#
#
# ---
#
# ### 🟢 **Sequências e Operações (P4.5 - P4.7)**
# - **Problema:**
#   Encontre a Transformada Z para:
#   1. A convolução de duas sequências.
#   2. A multiplicação de uma sequência por uma constante.
#   3. A resposta ao impulso de um sistema descrito por uma função de transferência.
#
# - **Objetivo:**
#   Aplicar operações básicas de processamento de sinais e validar os resultados.
#
#
# ---
#
# ### 🟢 **Convolução e Deconvolução (P4.8 - P4.10)**
# - **Problema:**
#   Resolve problemas envolvendo:
#   1. Convolução entre duas sequências.
#   2. Deconvolução para recuperar uma sequência original.
#   3. Propriedades gerais da convolução.
#
# - **Objetivo:**
#   Validar as propriedades de convolução e deconvolução, essenciais na análise de sistemas.
#
#
# ---
#
# ### 🟢 **Transformada Z Inversa (P4.11 - P4.12)**
# - **Problema:**
#   Encontre a Transformada Z inversa para:
#   1. \( \frac{1}{1 - az^{-1}} \).
#   2. \( \frac{z}{z - a} \).
#
# - **Objetivo:**
#   Determinar as sequências no domínio do tempo correspondentes.
#
#
# ---
#
# ### 🟢 **Resposta do Sistema (P4.13 - P4.14)**
# - **Problema:**
#   Calcule a resposta do sistema para:
#   1. A função delta \( \delta(n) \).
#   2. A função degrau \( u(n) \).
#
# - **Objetivo:**
#   Analisar como o sistema reage a entradas básicas.
#
#
# ---
#
# ### 🟢 **Função e Resposta do Sistema (P4.15 - P4.16)**
# - **Problema:**
#   Para uma função de transferência \( H(z) \), encontre:
#   1. A resposta a uma entrada específica.
#   2. A resposta a uma entrada periódica.
#
# - **Objetivo:**
#   Entender o comportamento do sistema frente a diferentes tipos de entrada.
#
#
# ---
#
# ### 🟢 **Comportamento de Sistemas (P4.17 - P4.18)**
# - **Problema:**
#   Determine o comportamento do sistema por meio de:
#   1. Equações diferenciais.
#   2. Convolução aplicada a entradas complexas.
#
# - **Objetivo:**
#   Aplicar equações diferenciais e convolução para entender respostas dinâmicas.
#
#
# ---
#
# ### 🟢 **Resposta em Estado Estacionário (P4.19 - P4.20)**
# - **Problema:**
#   Encontre a resposta estacionária para:
#   1. Entradas sinusoidais.
#   2. Entradas exponenciais.
#
# - **Objetivo:**
#   Analisar o comportamento do sistema a longo prazo.
#
#
# ---
#
# ### 🟢 **Análise de Filtros Digitais (P4.21 - P4.22)**
# - **Problema:**
#   Analise a resposta para:
#   1. Filtros passa-baixa e passa-alta.
#   2. Propriedades usando Transformada Z.
#
# - **Objetivo:**
#   Compreender como filtros digitais afetam sinais.
#
#
# ---
#
# ### 🟢 **Equações Diferenciais e Respostas (P4.23 - P4.26)**
# - **Problema:**
#   Resolva equações diferenciais e determine as respostas do sistema.
#
# - **Objetivo:**
#   Aplicar a Transformada Z para estudar sistemas dinâmicos.
#
#
# ---
