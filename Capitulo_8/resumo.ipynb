# %% [markdown]
# ---
#
# ### **Capítulo 8**
#
# Os filtros IIR (Infinite Impulse Response) desempenham um papel crucial no processamento de sinais devido à sua eficiência computacional. Ao contrário dos filtros FIR, os filtros IIR possuem resposta ao impulso infinita, permitindo realizar filtragens mais seletivas com menor ordem de filtro.
#
#
# ### Principais Pontos
#
# ---
#
# ### 🟢 **Tipos Especiais de filtros**
#
# Os filtros IIR podem ser projetados com diferentes características, dependendo das necessidades da aplicação. Alguns tipos especiais incluem:
#
# - **Resonadores Digitais (Digital Resonators):** Utilizados para realçar ou suprimir sinais em frequências específicas, sendo amplamente usados em síntese sonora e comunicações.
#
# - **Filtros Notch (Notch Filters):** Projetados para rejeitar uma frequência específica enquanto preservam as demais, muito utilizados na remoção de ruídos de linha elétrica.
#
# - **Filtros Comb (Comb Filters):** Caracterizados por uma resposta em frequência periódica, úteis para efeitos de eco e realce de harmônicos.
#
# - **Filtros Allpass (Allpass Filters):** Mantêm a magnitude do sinal inalterada enquanto modificam sua fase, sendo fundamentais em aplicações de correção de fase.
#
# - **Osciladores Digitais Sinusoidais (Digital Sinusoidal Oscillators):** Geram sinais senoidais estáveis e precisos, utilizados em modulação e geração de portadoras.
#
# ###
# ---
#
#
# ### 🟢 **Características dos Filtros Analógicos Prototípicos**
#
# O projeto de filtros IIR é baseado em filtros analógicos prototípicos, que servem como referência para a conversão digital. Os três principais protótipos de filtros passa-baixa utilizados incluem:
#
# <p style="background-color: #333333; color: #e6c87e; padding: 4px 8px; border-radius: 5px; display: block;">Filtro Butterworth:</p>
# Caracteriza-se por uma resposta de magnitude suave, sem ondulações na banda de passagem. Sua principal vantagem é a ausência de distorção na resposta em frequência, garantindo um comportamento uniforme.
#
# <p style="background-color: #333333; color: #e6c87e; padding: 4px 8px; border-radius: 5px; display: block;">Filtro Chebyshev:</p>
#
# - **Tipo I:** Apresenta uma transição mais acentuada entre as bandas de passagem e rejeição, mas com a presença de ondulações na banda de passagem.
#
# - **Tipo II:** Possui uma banda de passagem plana e ondulações na banda de rejeição, sendo útil quando a estabilidade da banda de passagem é prioritária.
#
# <p style="background-color: #333333; color: #e6c87e; padding: 4px 8px; border-radius: 5px; display: block;">Filtro Elíptico (Cauer):</p>
# Apresenta a resposta mais eficiente em termos de transição entre bandas, mas possui ondulações tanto na banda de passagem quanto na banda de rejeição. É ideal para aplicações onde uma transição rápida é essencial.
#
# ###
# ---
#
# ### 🟢 **Transformações de Filtros Analógicos para Digitais**
#
# As transformações de filtros analógicos para digitais são baseadas na preservação de diferentes características do sistema original. Existem três principais técnicas utilizadas:
#
# - **Transformação de Invariância ao Impulso (Impulse Invariance Transformation)** Essa técnica preserva a forma da resposta ao impulso do filtro analógico no filtro digital resultante. No entanto, pode introduzir aliasing se não for utilizada corretamente.
#
# - **Aproximação por Diferenças Finitas (Finite Difference Approximation):** Converte equações diferenciais contínuas em equações de diferenças discretas, permitindo a implementação digital direta de um sistema analógico.
#
# - **Transformação Bilinear (Bilinear Transformation):** A técnica mais utilizada na prática, pois preserva a função de transferência do sistema e evita aliasing ao mapear a resposta analógica para o domínio digital de forma não linear.
#
# Cada uma dessas técnicas possui vantagens e limitações, e a escolha depende dos requisitos do sistema e da aplicação desejada.
#
# ###
# ---
#
# ### 🟢 **Projeto de Filtros Passa-Baixa no MATLAB**
#
# O MATLAB oferece funções para projetar filtros IIR passa-baixa de forma eficiente:
#
# - **butter(N, Wn):** Implementa um filtro Butterworth de ordem N com frequência de corte Wn.
#
# - **cheby1(N, Rp, Wn):** Cria um filtro Chebyshev Tipo I com ondulação Rp na banda de passagem.
#
# - **cheby2(N, Rs, Wn):** Gera um filtro Chebyshev Tipo II com atenuação Rs na banda de rejeição.
#
# - **ellip(N, Rp, Rs, Wn):** Projeta um filtro elíptico com ondulação Rp na banda de passagem e atenuação Rs na banda de rejeição.
#
# Essas funções permitem ajustar parâmetros como a ordem do filtro e a frequência de corte para atender às necessidades do projeto.
#
# ###
# ---
#
# ### 🟢 **Transformações de Banda de Frequência**
#
# Além do projeto de filtros passa-baixa, é possível transformar esses filtros em outros tipos de filtros:
#
# - **Passa-alta:** Obtido invertendo a resposta de frequência do filtro passa-baixa.
#
# - **Passa-faixa:** Criado a partir de uma combinação de dois filtros passa-baixa e passa-alta.
#
# - **Rejeita-faixa (Notch):** Usado para remover componentes de frequência específicas, como ruído de linha elétrica.
#
# ###
# ---
#
# 📌 Conclusão
#
# O projeto de filtros IIR é um processo essencial no processamento de sinais, permitindo maior seletividade com menor ordem de filtro. A seleção do protótipo analógico adequado e sua conversão para um filtro digital eficiente são passos fundamentais.
#
# Diferentes técnicas de transformação, como invariância ao impulso, aproximação por diferenças finitas e transformação bilinear, garantem a adaptação dos filtros analógicos ao domínio digital, cada uma com suas vantagens e limitações. Entre elas, a transformação bilinear é a mais amplamente utilizada devido à sua capacidade de preservar a resposta do sistema e evitar aliasing.
#
# A flexibilidade dos filtros IIR permite sua aplicação em diversos contextos, desde comunicação até processamento de áudio, tornando seu projeto um tema essencial para engenheiros e pesquisadores da área.
